# %%
#two core objects in pandas libraray - i)DataFrame ii)Series
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. 
#DataFrame
# Each entry corresponds to a row (or record) and a column.
# The list of row labels used in a DataFrame is known as an Index
# Series
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list.
# And in fact you can create one with nothing more than a list:

#loc and iloc accessor operator
# Both loc and iloc are row-first, column-second
# loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters.
#iloc index based selection

# %%
import pandas as pd
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
import pandas as pd
reviews = pd.read_csv(r"C:\Users\VI00592\GitHub\kaggle_learn\pandas/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
#              ...
# 75%          91.000000
# max         100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.taster_name.value_counts()
# Out:
# taster_name
# Roger Voss           25514
# Michael Schachner    15134
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 19, dtype: int64

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews["country"]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %%
#loc and iloc accessor operator
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
#row
reviews.loc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
#1st column (0,1,2)
reviews.iloc[0:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[[0,1,2,3,4,5],0]
# Out:
# 0       Italy
# 1    Portugal
#        ...
# 4          US
# 5       Spain
# Name: country, Length: 6, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ...               ...                   ...     ...
# 129969     Roger Voss            @vossroger      90
# 129970     Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %%
# The set_index() method can be used to do the job. Here is what happens when we set_index to the title field:
reviews.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
reviews.country =='Italy'
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[(reviews.country.isin(['France','Italy']))]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
#isnull and notnull
reviews.loc[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
#indexing reverse
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
#Summary Functions and maps

# %%
import pandas as pd
reviews = pd.read_csv(r"C:\Users\VI00592\GitHub\kaggle_learn\pandas/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)

# %% [raw]
# reviews

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(func, *iterables) --> map object
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.points.mean()
# Out:
# 88.44713820775404

# %%
reviews.country + " - " + reviews.region_1
# Out:
# 0            Italy - Etna
# 1                     NaN
#                ...
# 129969    France - Alsace
# 129970    France - Alsace
# Length: 129971, dtype: object

# %%
##########Grouping and sorting

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
reviews.points.value_counts()
# Out:
# points
# 88     17207
# 87     16933
#        ...
# 99        33
# 100       19
# Name: count, Length: 21, dtype: int64

# %%
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# ...              ...            ...
# 75%        91.000000      42.000000
# max       100.000000    3300.000000
#
# [8 rows x 2 columns]

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0]).head()
# Out:
# winery
# 1+1=3                                  1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                         10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine           100 Percent Wine 2015 Moscato (California)
# 1000 Stories        1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green               1070 Green 2011 Sauvignon Blanc (Rutherford)
# dtype: object

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
# ...

# %%
import pandas as pd

data = {
  "sales": [23, 34, 56],
  "age": [50, 40, 30]
}

df = pd.DataFrame(data)

print(df.idxmax())
# Out:
# sales    2
# age      0
# dtype: int64

# %%
reviews.groupby(['country']).price.agg([len, min, max]).sort_values(by ='min',ascending = False)
# Out:
# C:\Users\VI00592\AppData\Local\Temp\ipykernel_2976\3109048223.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby(['country']).price.agg([len, min, max]).sort_values(by ='min',ascending = False)
# C:\Users\VI00592\AppData\Local\Temp\ipykernel_2976\3109048223.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby(['country']).price.agg([len, min, max]).sort_values(by ='min',ascending = False)
#               len   min    max
# country
# England        74  25.0   95.0
# Switzerland     7  21.0  160.0
# ...           ...   ...    ...
# Argentina    3800   4.0  230.0
# ...

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed.sort_values(by='len',ascending = False)
# Out:
#                       len
# country province
# US      California  36247
#         Washington   8639
# ...                   ...
# Chile   Coelemu         1
# Greece  Beotia          1
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
#######Grouping and sorting exercise####### 
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.groupby('taster_twitter_handle').size()
# Out:
# taster_twitter_handle
# @AnneInVino        3685
# @JoeCz             5147
#                    ...
# @winewchristina       6
# @worldwineguys     1005
# Length: 15, dtype: int64

# %%
reviews.groupby('price').points.min()
# Out:
# price
# 4.0       82
# 5.0       80
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
reviews.groupby('price')['points'].max().sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
 reviews.groupby('variety').price.agg([min, max])
# Out:
# C:\Users\VI00592\AppData\Local\Temp\ipykernel_2976\678324134.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   reviews.groupby('variety').price.agg([min, max])
# C:\Users\VI00592\AppData\Local\Temp\ipykernel_2976\678324134.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reviews.groupby('variety').price.agg([min, max])
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]
